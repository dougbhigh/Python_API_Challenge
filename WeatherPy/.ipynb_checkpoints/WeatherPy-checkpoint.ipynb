# %% [markdown]
# WeatherPy

# %% [markdown]
#    Looking at scatterplot and linear regression for different weather variables against lattitude shows several features.  Most noteably is the further from lattitude of zero (equator), the lower the temperatures.  Since the air is mostly warmed via solar radiation and the earth titlts its axis to the sun across the equator, the equatorial regions see more sun and therefore more heat.  Further, it is currently summer in the northern hemisphere*', meaning the sun is 'above the equator', creating warmer air north of the equator.
#   As far as the other variables (wind speed, humidity, and cloud cover) are concerned, there does not appear to be any causation that the distance from the equator, either north or south, has any affect on them.  Although there are some noticeable differences between the northern and southern hemispheres, in general they should even out with a larger sampling across various points in time as weather conditions move and change.  Figure 10 in section 17 does show a regression line suggesting it would be cloudier further south of the equator, though the data points on the underlying scatter plot do not suggest an actual relationship.
#
# *' code has been rerun on 5/10/2021, where it is currently spring in the northern hemisphere.

# %% [raw]
# ##########################################################################################
# #  RUT-SOM-DATA-PT-06-2020-U-C                                              Douglas High #
# #   Python API Challenge                                                   July 20, 2020 #
# #      >WeatherPy                                                                        #
# #   - get random list of geo-coordinates, convert to nearby cities.                      #
# #   - call openweather and extract city weather conditions, put in df and output file.   #
# #   - create scatterplots and regression lines for various criteria.                     #
# #   - write function to create scatterplot, regression line graph, or both.              #
# ##########################################################################################

# %%
# %matplotlib notebook
#############################################################
#00       I/O                                               #
#   a- import libraries and api key.                        #
#   b- associate output file to variable.                   #
#   c- set lat & lng parameter for call to np in step 01.   #
#############################################################

#a
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
from citipy import citipy
import json
from api_keys import weather_api_key
import datetime as dt

# b
output_data_file = "output_data/cities.csv"

#c
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#######################################################
#01        CityList                                   #
#   a- get random lat and long coordinates from np.   #
#   b- call citypy with coords, get nearest city,     #
#      add to cities list if new.                     #
#   c- verify at least 500 cities via print.          #
#######################################################

#a
lat_lngs = []
cities = []
countries = []

lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#b
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)
#c
print(len(cities))
# Out:
# 599

# %%
##############################################################################
#02        Fill Dataframe                                                    #
#   a- create df from cities, add fields to populate.                        # 
#   b- set up url base for calls to openweather.                             #
#     - create list for indexes, to delete if no weather records for city.   #
#     - subtract utc offset from utc epoch time, convert, add to df.         #         
#   c- retrieve info for each city, populate df.                             #
#   d- delete cities from df if no weather records, check remaining count.   #
##############################################################################

#a
city_weather = pd.DataFrame({"city": cities})
city_weather["temp"] = ""
city_weather["humid"] = ""
city_weather["wind"] = ""
city_weather["clouds"] = ""
city_weather["lat"] = ""
city_weather["lng"] = ""
city_weather["maxtemp"] = ""
city_weather["country"] = ""
city_weather["local_date_time"] = ""

#b
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
del_indexes = []

#c
for x, row in city_weather.iterrows():
    print("*" * 55)
    current_city = city_weather["city"][x]
    print(f"checking openweather for city number {x+1} : {current_city}")
    response = requests.get(query_url + row["city"]).json()
    
    try:
        city_weather.loc[x, "temp"] = response["main"]["temp"]
        city_weather.loc[x, "humid"] = response["main"]["humidity"]
        city_weather.loc[x, "wind"] = response["wind"]["speed"]
        city_weather.loc[x, "clouds"] = response["clouds"]["all"]                 
        city_weather.loc[x, "lat"] = response["coord"]["lat"]
        city_weather.loc[x, "lng"] = response["coord"]["lon"]
        city_weather.loc[x, "maxtemp"] = response["main"]["temp_max"]
        city_weather.loc[x, "country"] = response["sys"]["country"]
        utc_off = response["timezone"]                            # local time offset in seconds from UTC
        utc_time = response["dt"]                                 # current UTC in epoch time
        local_time_epoch = utc_time + utc_off
        local_time = dt.datetime.fromtimestamp(local_time_epoch)  # retrieve fomatted gregorian date and time from epoch
        city_weather.loc[x, "local_date_time"] = local_time  
                
    except (KeyError):
        print('\033[91m' + "*** No Weather Record, removing from file ***" + '\033[0m')
        del_indexes.append(x)
    except (IndexError):
        print('\033[91m' + "*** Index Error, removing from file ***" + '\033[0m')
        del_indexes.append(x)
#d
if len(del_indexes) > 0:
    city_weather.drop(del_indexes, inplace=True)
    city_weather.reset_index(inplace=True, drop=True)
    if len(city_weather) < 500:
        print('\033[91m' + "WARNING!!  Number of cities left = " + str(len(city_weather)) + '\033[0m')
    else:
        print(f"number of cities left = {len(city_weather)}")
# Out:
# *******************************************************
# checking openweather for city number 1 : worthington
# *******************************************************
# checking openweather for city number 2 : port elizabeth
# *******************************************************
# checking openweather for city number 3 : mayor pablo lagerenza
# *******************************************************
# checking openweather for city number 4 : otradnoye
# *******************************************************
# checking openweather for city number 5 : asau
# *******************************************************
# checking openweather for city number 6 : rivadavia
# *******************************************************
# checking openweather for city number 7 : busselton
# *******************************************************
# checking openweather for city number 8 : cape town
# *******************************************************
# checking openweather for city number 9 : baiyin
# *******************************************************
# checking openweather for city number 10 : albany
# *******************************************************
# checking openweather for city number 11 : illoqqortoormiut
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 12 : sao filipe
# *******************************************************
# checking openweather for city number 13 : bria
# *******************************************************
# checking openweather for city number 14 : poum
# *******************************************************
# checking openweather for city number 15 : yellowknife
# *******************************************************
# checking openweather for city number 16 : ribeira grande
# *******************************************************
# checking openweather for city number 17 : iqaluit
# *******************************************************
# checking openweather for city number 18 : rikitea
# *******************************************************
# checking openweather for city number 19 : saint-philippe
# *******************************************************
# checking openweather for city number 20 : conakry
# *******************************************************
# checking openweather for city number 21 : mataura
# *******************************************************
# checking openweather for city number 22 : kavieng
# *******************************************************
# checking openweather for city number 23 : atkinson
# *******************************************************
# checking openweather for city number 24 : belyy yar
# *******************************************************
# checking openweather for city number 25 : paamiut
# *******************************************************
# checking openweather for city number 26 : puerto ayora
# *******************************************************
# checking openweather for city number 27 : maragogi
# *******************************************************
# checking openweather for city number 28 : pinega
# *******************************************************
# checking openweather for city number 29 : tabiauea
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 30 : ushuaia
# *******************************************************
# checking openweather for city number 31 : fairbanks
# *******************************************************
# checking openweather for city number 32 : punta arenas
# *******************************************************
# checking openweather for city number 33 : belushya guba
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 34 : el balyana
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 35 : souillac
# *******************************************************
# checking openweather for city number 36 : jamestown
# *******************************************************
# checking openweather for city number 37 : atuona
# *******************************************************
# checking openweather for city number 38 : mao
# *******************************************************
# checking openweather for city number 39 : butaritari
# *******************************************************
# checking openweather for city number 40 : ancud
# *******************************************************
# checking openweather for city number 41 : vaini
# *******************************************************
# checking openweather for city number 42 : kapaa
# *******************************************************
# checking openweather for city number 43 : centralia
# *******************************************************
# checking openweather for city number 44 : sentyabrskiy
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 45 : lebu
# *******************************************************
# checking openweather for city number 46 : nizhneyansk
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 47 : roma
# *******************************************************
# checking openweather for city number 48 : hithadhoo
# *******************************************************
# checking openweather for city number 49 : guymon
# *******************************************************
# checking openweather for city number 50 : ano mera
# *******************************************************
# checking openweather for city number 51 : barentsburg
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 52 : krasnoselkup
# *******************************************************
# checking openweather for city number 53 : tiksi
# *******************************************************
# checking openweather for city number 54 : cabo san lucas
# *******************************************************
# checking openweather for city number 55 : thompson
# *******************************************************
# checking openweather for city number 56 : alta gracia
# *******************************************************
# checking openweather for city number 57 : vostok
# *******************************************************
# checking openweather for city number 58 : chokurdakh
# *******************************************************
# checking openweather for city number 59 : constitucion
# *******************************************************
# checking openweather for city number 60 : vila franca do campo
# *******************************************************
# checking openweather for city number 61 : east london
# *******************************************************
# checking openweather for city number 62 : kingman
# *******************************************************
# checking openweather for city number 63 : bredasdorp
# *******************************************************
# checking openweather for city number 64 : clyde river
# *******************************************************
# checking openweather for city number 65 : bethel
# *******************************************************
# checking openweather for city number 66 : eldorado
# *******************************************************
# checking openweather for city number 67 : ojinaga
# *******************************************************
# checking openweather for city number 68 : taolanaro
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 69 : harwich
# *******************************************************
# checking openweather for city number 70 : emerald
# *******************************************************
# checking openweather for city number 71 : acapulco
# *******************************************************
# checking openweather for city number 72 : karratha
# *******************************************************
# checking openweather for city number 73 : saldanha
# *******************************************************
# checking openweather for city number 74 : chuy
# *******************************************************
# checking openweather for city number 75 : abong mbang
# *******************************************************
# checking openweather for city number 76 : nosy varika
# *******************************************************
# checking openweather for city number 77 : mys shmidta
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 78 : kamenskoye
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 79 : mapiripan
# *******************************************************
# checking openweather for city number 80 : torbay
# *******************************************************
# checking openweather for city number 81 : geraldton
# *******************************************************
# checking openweather for city number 82 : tasiilaq
# *******************************************************
# checking openweather for city number 83 : carnarvon
# *******************************************************
# checking openweather for city number 84 : merauke
# *******************************************************
# checking openweather for city number 85 : bluff
# *******************************************************
# checking openweather for city number 86 : grand river south east
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 87 : anloga
# *******************************************************
# checking openweather for city number 88 : bracigovo
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 89 : gazanjyk
# *******************************************************
# checking openweather for city number 90 : antunez
# *******************************************************
# checking openweather for city number 91 : dawson creek
# *******************************************************
# checking openweather for city number 92 : tual
# *******************************************************
# checking openweather for city number 93 : khatanga
# *******************************************************
# checking openweather for city number 94 : samusu
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 95 : nyurba
# *******************************************************
# checking openweather for city number 96 : saleaula
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 97 : rocha
# *******************************************************
# checking openweather for city number 98 : saskylakh
# *******************************************************
# checking openweather for city number 99 : atasu
# *******************************************************
# checking openweather for city number 100 : svetlogorsk
# *******************************************************
# checking openweather for city number 101 : poplar bluff
# *******************************************************
# checking openweather for city number 102 : bud
# *******************************************************
# checking openweather for city number 103 : hobart
# *******************************************************
# checking openweather for city number 104 : nikolskoye
# *******************************************************
# checking openweather for city number 105 : srednekolymsk
# *******************************************************
# checking openweather for city number 106 : mayo
# *******************************************************
# checking openweather for city number 107 : hermanus
# *******************************************************
# checking openweather for city number 108 : bridlington
# *******************************************************
# checking openweather for city number 109 : ostrovnoy
# *******************************************************
# checking openweather for city number 110 : amahai
# *******************************************************
# checking openweather for city number 111 : victoria
# *******************************************************
# checking openweather for city number 112 : henties bay
# *******************************************************
# checking openweather for city number 113 : olga
# *******************************************************
# checking openweather for city number 114 : tete
# *******************************************************
# checking openweather for city number 115 : saint george
# *******************************************************
# checking openweather for city number 116 : lavrentiya
# *******************************************************
# checking openweather for city number 117 : baykit
# *******************************************************
# checking openweather for city number 118 : tuktoyaktuk
# *******************************************************
# checking openweather for city number 119 : pullman
# *******************************************************
# checking openweather for city number 120 : barrow
# *******************************************************
# checking openweather for city number 121 : nome
# *******************************************************
# checking openweather for city number 122 : estevan
# *******************************************************
# checking openweather for city number 123 : louisbourg
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 124 : itarsi
# *******************************************************
# checking openweather for city number 125 : georgetown
# *******************************************************
# checking openweather for city number 126 : takaungu
# *******************************************************
# checking openweather for city number 127 : dzhusaly
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 128 : canguaretama
# *******************************************************
# checking openweather for city number 129 : samarai
# *******************************************************
# checking openweather for city number 130 : codrington
# *******************************************************
# checking openweather for city number 131 : hamilton
# *******************************************************
# checking openweather for city number 132 : potiskum
# *******************************************************
# checking openweather for city number 133 : port alfred
# *******************************************************
# checking openweather for city number 134 : piterka
# *******************************************************
# checking openweather for city number 135 : sulangan
# *******************************************************
# checking openweather for city number 136 : sisimiut
# *******************************************************
# checking openweather for city number 137 : havelock
# *******************************************************
# checking openweather for city number 138 : ust-kuyga
# *******************************************************
# checking openweather for city number 139 : varhaug
# *******************************************************
# checking openweather for city number 140 : cherskiy
# *******************************************************
# checking openweather for city number 141 : castro
# *******************************************************
# checking openweather for city number 142 : yar-sale
# *******************************************************
# checking openweather for city number 143 : hasaki
# *******************************************************
# checking openweather for city number 144 : sao felix do xingu
# *******************************************************
# checking openweather for city number 145 : hami
# *******************************************************
# checking openweather for city number 146 : arraial do cabo
# *******************************************************
# checking openweather for city number 147 : zhigansk
# *******************************************************
# checking openweather for city number 148 : avarua
# *******************************************************
# checking openweather for city number 149 : inhambane
# *******************************************************
# checking openweather for city number 150 : nizwa
# *******************************************************
# checking openweather for city number 151 : lyuban
# *******************************************************
# checking openweather for city number 152 : airai
# *******************************************************
# checking openweather for city number 153 : paonta sahib
# *******************************************************
# checking openweather for city number 154 : umzimvubu
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 155 : kocerin
# *******************************************************
# checking openweather for city number 156 : novy malin
# *******************************************************
# checking openweather for city number 157 : ilulissat
# *******************************************************
# checking openweather for city number 158 : hambantota
# *******************************************************
# checking openweather for city number 159 : labytnangi
# *******************************************************
# checking openweather for city number 160 : padang
# *******************************************************
# checking openweather for city number 161 : upernavik
# *******************************************************
# checking openweather for city number 162 : komsomolskiy
# *******************************************************
# checking openweather for city number 163 : sungaipenuh
# *******************************************************
# checking openweather for city number 164 : malakal
# *******************************************************
# checking openweather for city number 165 : phan thiet
# *******************************************************
# checking openweather for city number 166 : nelson bay
# *******************************************************
# checking openweather for city number 167 : vardo
# *******************************************************
# checking openweather for city number 168 : mehamn
# *******************************************************
# checking openweather for city number 169 : hit
# *******************************************************
# checking openweather for city number 170 : dikson
# *******************************************************
# checking openweather for city number 171 : dunedin
# *******************************************************
# checking openweather for city number 172 : kodiak
# *******************************************************
# checking openweather for city number 173 : karaul
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 174 : batemans bay
# *******************************************************
# checking openweather for city number 175 : ixtapa
# *******************************************************
# checking openweather for city number 176 : akersberga
# *******************************************************
# checking openweather for city number 177 : tumannyy
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 178 : one hundred mile house
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 179 : lagoa
# *******************************************************
# checking openweather for city number 180 : teguise
# *******************************************************
# checking openweather for city number 181 : senmonorom
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 182 : umm durman
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 183 : alice springs
# *******************************************************
# checking openweather for city number 184 : bonavista
# *******************************************************
# checking openweather for city number 185 : siderno
# *******************************************************
# checking openweather for city number 186 : miramar
# *******************************************************
# checking openweather for city number 187 : bundaberg
# *******************************************************
# checking openweather for city number 188 : payo
# *******************************************************
# checking openweather for city number 189 : waipawa
# *******************************************************
# checking openweather for city number 190 : bengkulu
# *******************************************************
# checking openweather for city number 191 : tsihombe
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 192 : temaraia
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 193 : anar darreh
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 194 : san quintin
# *******************************************************
# checking openweather for city number 195 : bairiki
# *******************************************************
# checking openweather for city number 196 : shetpe
# *******************************************************
# checking openweather for city number 197 : miraflores
# *******************************************************
# checking openweather for city number 198 : kavaratti
# *******************************************************
# checking openweather for city number 199 : salym
# *******************************************************
# checking openweather for city number 200 : tazovskiy
# *******************************************************
# checking openweather for city number 201 : diffa
# *******************************************************
# checking openweather for city number 202 : ypsilanti
# *******************************************************
# checking openweather for city number 203 : nanortalik
# *******************************************************
# checking openweather for city number 204 : bereda
# *******************************************************
# checking openweather for city number 205 : lebedyn
# *******************************************************
# checking openweather for city number 206 : vao
# *******************************************************
# checking openweather for city number 207 : omboue
# *******************************************************
# checking openweather for city number 208 : namatanai
# *******************************************************
# checking openweather for city number 209 : longyearbyen
# *******************************************************
# checking openweather for city number 210 : carlyle
# *******************************************************
# checking openweather for city number 211 : takhtamygda
# *******************************************************
# checking openweather for city number 212 : pisco
# *******************************************************
# checking openweather for city number 213 : hilo
# *******************************************************
# checking openweather for city number 214 : hofn
# *******************************************************
# checking openweather for city number 215 : haines junction
# *******************************************************
# checking openweather for city number 216 : marshall
# *******************************************************
# checking openweather for city number 217 : erzurum
# *******************************************************
# checking openweather for city number 218 : traiguen
# *******************************************************
# checking openweather for city number 219 : coquimbo
# *******************************************************
# checking openweather for city number 220 : qaanaaq
# *******************************************************
# checking openweather for city number 221 : wanning
# *******************************************************
# checking openweather for city number 222 : maun
# *******************************************************
# checking openweather for city number 223 : muros
# *******************************************************
# checking openweather for city number 224 : pevek
# *******************************************************
# checking openweather for city number 225 : phan rang
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 226 : kaitangata
# *******************************************************
# checking openweather for city number 227 : batie
# *******************************************************
# checking openweather for city number 228 : lorengau
# *******************************************************
# checking openweather for city number 229 : fort smith
# *******************************************************
# checking openweather for city number 230 : ahipara
# *******************************************************
# checking openweather for city number 231 : casa grande
# *******************************************************
# checking openweather for city number 232 : zlobin
# *******************************************************
# checking openweather for city number 233 : bubaque
# *******************************************************
# checking openweather for city number 234 : mackenzie
# *******************************************************
# checking openweather for city number 235 : tuatapere
# *******************************************************
# checking openweather for city number 236 : trelew
# *******************************************************
# checking openweather for city number 237 : sao joao da barra
# *******************************************************
# checking openweather for city number 238 : aykhal
# *******************************************************
# checking openweather for city number 239 : guerrero negro
# *******************************************************
# checking openweather for city number 240 : berberati
# *******************************************************
# checking openweather for city number 241 : longonjo
# *******************************************************
# checking openweather for city number 242 : kirksville
# *******************************************************
# checking openweather for city number 243 : grand baie
# *******************************************************
# checking openweather for city number 244 : katherine
# *******************************************************
# checking openweather for city number 245 : pierre
# *******************************************************
# checking openweather for city number 246 : port lincoln
# *******************************************************
# checking openweather for city number 247 : mar del plata
# *******************************************************
# checking openweather for city number 248 : broken hill
# *******************************************************
# checking openweather for city number 249 : bowen
# *******************************************************
# checking openweather for city number 250 : wa
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 251 : barawe
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 252 : wahran
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 253 : sinnamary
# *******************************************************
# checking openweather for city number 254 : tarko-sale
# *******************************************************
# checking openweather for city number 255 : severo-kurilsk
# *******************************************************
# checking openweather for city number 256 : sechura
# *******************************************************
# checking openweather for city number 257 : quzhou
# *******************************************************
# checking openweather for city number 258 : hobyo
# *******************************************************
# checking openweather for city number 259 : grand gaube
# *******************************************************
# checking openweather for city number 260 : shumikha
# *******************************************************
# checking openweather for city number 261 : kruisfontein
# *******************************************************
# checking openweather for city number 262 : faanui
# *******************************************************
# checking openweather for city number 263 : attawapiskat
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 264 : adrar
# *******************************************************
# checking openweather for city number 265 : eydhafushi
# *******************************************************
# checking openweather for city number 266 : ponta do sol
# *******************************************************
# checking openweather for city number 267 : ketchikan
# *******************************************************
# checking openweather for city number 268 : provideniya
# *******************************************************
# checking openweather for city number 269 : pangody
# *******************************************************
# checking openweather for city number 270 : broome
# *******************************************************
# checking openweather for city number 271 : crawfordsville
# *******************************************************
# checking openweather for city number 272 : kirakira
# *******************************************************
# checking openweather for city number 273 : ishigaki
# *******************************************************
# checking openweather for city number 274 : zhezkazgan
# *******************************************************
# checking openweather for city number 275 : tambilil
# *******************************************************
# checking openweather for city number 276 : pajan
# *******************************************************
# checking openweather for city number 277 : carrick-on-suir
# *******************************************************
# checking openweather for city number 278 : arman
# *******************************************************
# checking openweather for city number 279 : lewistown
# *******************************************************
# checking openweather for city number 280 : bambous virieux
# *******************************************************
# checking openweather for city number 281 : dingle
# *******************************************************
# checking openweather for city number 282 : marsa matruh
# *******************************************************
# checking openweather for city number 283 : coihaique
# *******************************************************
# checking openweather for city number 284 : kuah
# *******************************************************
# checking openweather for city number 285 : new norfolk
# *******************************************************
# checking openweather for city number 286 : winneba
# *******************************************************
# checking openweather for city number 287 : nishihara
# *******************************************************
# checking openweather for city number 288 : lasa
# *******************************************************
# checking openweather for city number 289 : shimoda
# *******************************************************
# checking openweather for city number 290 : sur
# *******************************************************
# checking openweather for city number 291 : ngukurr
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 292 : gizo
# *******************************************************
# checking openweather for city number 293 : surt
# *******************************************************
# checking openweather for city number 294 : aklavik
# *******************************************************
# checking openweather for city number 295 : kasongo-lunda
# *******************************************************
# checking openweather for city number 296 : broadstairs
# *******************************************************
# checking openweather for city number 297 : galle
# *******************************************************
# checking openweather for city number 298 : banyo
# *******************************************************
# checking openweather for city number 299 : yumen
# *******************************************************
# checking openweather for city number 300 : quang ngai
# *******************************************************
# checking openweather for city number 301 : zeya
# *******************************************************
# checking openweather for city number 302 : svetlyy
# *******************************************************
# checking openweather for city number 303 : gat
# *******************************************************
# checking openweather for city number 304 : norman wells
# *******************************************************
# checking openweather for city number 305 : klaksvik
# *******************************************************
# checking openweather for city number 306 : salalah
# *******************************************************
# checking openweather for city number 307 : rio grande
# *******************************************************
# checking openweather for city number 308 : sitka
# *******************************************************
# checking openweather for city number 309 : kampot
# *******************************************************
# checking openweather for city number 310 : mogadishu
# *******************************************************
# checking openweather for city number 311 : darapidap
# *******************************************************
# checking openweather for city number 312 : bouna
# *******************************************************
# checking openweather for city number 313 : taoudenni
# *******************************************************
# checking openweather for city number 314 : pedernales
# *******************************************************
# checking openweather for city number 315 : severnyy
# *******************************************************
# checking openweather for city number 316 : alofi
# *******************************************************
# checking openweather for city number 317 : san cristobal
# *******************************************************
# checking openweather for city number 318 : talnakh
# *******************************************************
# checking openweather for city number 319 : mahebourg
# *******************************************************
# checking openweather for city number 320 : morros
# *******************************************************
# checking openweather for city number 321 : sande
# *******************************************************
# checking openweather for city number 322 : caravelas
# *******************************************************
# checking openweather for city number 323 : hoxter
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 324 : wewak
# *******************************************************
# checking openweather for city number 325 : swan river
# *******************************************************
# checking openweather for city number 326 : halifax
# *******************************************************
# checking openweather for city number 327 : atambua
# *******************************************************
# checking openweather for city number 328 : tautira
# *******************************************************
# checking openweather for city number 329 : altay
# *******************************************************
# checking openweather for city number 330 : beyneu
# *******************************************************
# checking openweather for city number 331 : deer lake
# *******************************************************
# checking openweather for city number 332 : bambanglipuro
# *******************************************************
# checking openweather for city number 333 : isangel
# *******************************************************
# checking openweather for city number 334 : camacha
# *******************************************************
# checking openweather for city number 335 : shaartuz
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 336 : inuvik
# *******************************************************
# checking openweather for city number 337 : qasigiannguit
# *******************************************************
# checking openweather for city number 338 : ganzhou
# *******************************************************
# checking openweather for city number 339 : petropavlovsk-kamchatskiy
# *******************************************************
# checking openweather for city number 340 : ugoofaaru
# *******************************************************
# checking openweather for city number 341 : khammam
# *******************************************************
# checking openweather for city number 342 : vaitupu
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 343 : avera
# *******************************************************
# checking openweather for city number 344 : gap
# *******************************************************
# checking openweather for city number 345 : bilibino
# *******************************************************
# checking openweather for city number 346 : sao borja
# *******************************************************
# checking openweather for city number 347 : touros
# *******************************************************
# checking openweather for city number 348 : guilin
# *******************************************************
# checking openweather for city number 349 : voyvozh
# *******************************************************
# checking openweather for city number 350 : traverse city
# *******************************************************
# checking openweather for city number 351 : shchelyayur
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 352 : tottori
# *******************************************************
# checking openweather for city number 353 : kosa
# *******************************************************
# checking openweather for city number 354 : vazante
# *******************************************************
# checking openweather for city number 355 : leningradskiy
# *******************************************************
# checking openweather for city number 356 : bandarbeyla
# *******************************************************
# checking openweather for city number 357 : lazaro cardenas
# *******************************************************
# checking openweather for city number 358 : warqla
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 359 : hokitika
# *******************************************************
# checking openweather for city number 360 : kirkenaer
# *******************************************************
# checking openweather for city number 361 : tuy hoa
# *******************************************************
# checking openweather for city number 362 : beringovskiy
# *******************************************************
# checking openweather for city number 363 : kolokani
# *******************************************************
# checking openweather for city number 364 : semey
# *******************************************************
# checking openweather for city number 365 : nexo
# *******************************************************
# checking openweather for city number 366 : corinto
# *******************************************************
# checking openweather for city number 367 : atlantic city
# *******************************************************
# checking openweather for city number 368 : batticaloa
# *******************************************************
# checking openweather for city number 369 : umm kaddadah
# *******************************************************
# checking openweather for city number 370 : jinxiang
# *******************************************************
# checking openweather for city number 371 : doha
# *******************************************************
# checking openweather for city number 372 : amderma
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 373 : tezu
# *******************************************************
# checking openweather for city number 374 : dubna
# *******************************************************
# checking openweather for city number 375 : talaya
# *******************************************************
# checking openweather for city number 376 : la palma
# *******************************************************
# checking openweather for city number 377 : portland
# *******************************************************
# checking openweather for city number 378 : rabo de peixe
# *******************************************************
# checking openweather for city number 379 : alta floresta
# *******************************************************
# checking openweather for city number 380 : santo domingo
# *******************************************************
# checking openweather for city number 381 : kudat
# *******************************************************
# checking openweather for city number 382 : pakwach
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 383 : teya
# *******************************************************
# checking openweather for city number 384 : khash
# *******************************************************
# checking openweather for city number 385 : gulshat
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 386 : deputatskiy
# *******************************************************
# checking openweather for city number 387 : prado
# *******************************************************
# checking openweather for city number 388 : grindavik
# *******************************************************
# checking openweather for city number 389 : emba
# *******************************************************
# checking openweather for city number 390 : lahij
# *******************************************************
# checking openweather for city number 391 : salisbury
# *******************************************************
# checking openweather for city number 392 : egvekinot
# *******************************************************
# checking openweather for city number 393 : jhelum
# *******************************************************
# checking openweather for city number 394 : placido de castro
# *******************************************************
# checking openweather for city number 395 : mbacke
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 396 : chara
# *******************************************************
# checking openweather for city number 397 : abu kamal
# *******************************************************
# checking openweather for city number 398 : tura
# *******************************************************
# checking openweather for city number 399 : dakar
# *******************************************************
# checking openweather for city number 400 : panguipulli
# *******************************************************
# checking openweather for city number 401 : povolzhskiy
# *******************************************************
# checking openweather for city number 402 : ashoknagar
# *******************************************************
# checking openweather for city number 403 : islamkot
# *******************************************************
# checking openweather for city number 404 : datia
# *******************************************************
# checking openweather for city number 405 : meulaboh
# *******************************************************
# checking openweather for city number 406 : tilichiki
# *******************************************************
# checking openweather for city number 407 : gamba
# *******************************************************
# checking openweather for city number 408 : aswan
# *******************************************************
# checking openweather for city number 409 : cuenca
# *******************************************************
# checking openweather for city number 410 : tsuyama
# *******************************************************
# checking openweather for city number 411 : alugan
# *******************************************************
# checking openweather for city number 412 : khandyga
# *******************************************************
# checking openweather for city number 413 : kholtoson
# *******************************************************
# checking openweather for city number 414 : cutzamala
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 415 : soe
# *******************************************************
# checking openweather for city number 416 : sabang
# *******************************************************
# checking openweather for city number 417 : strelka
# *******************************************************
# checking openweather for city number 418 : kismayo
# *******************************************************
# checking openweather for city number 419 : the valley
# *******************************************************
# checking openweather for city number 420 : narsaq
# *******************************************************
# checking openweather for city number 421 : tramore
# *******************************************************
# checking openweather for city number 422 : pareora
# *******************************************************
# checking openweather for city number 423 : maniitsoq
# *******************************************************
# checking openweather for city number 424 : safaga
# *******************************************************
# checking openweather for city number 425 : rawson
# *******************************************************
# checking openweather for city number 426 : imeni poliny osipenko
# *******************************************************
# checking openweather for city number 427 : avaton
# ...
# checking openweather for city number 457 : ambulu
# *******************************************************
# checking openweather for city number 458 : huanuni
# *******************************************************
# checking openweather for city number 459 : rio tercero
# *******************************************************
# checking openweather for city number 460 : muhos
# *******************************************************
# checking openweather for city number 461 : santa cruz de tenerife
# *******************************************************
# checking openweather for city number 462 : wattegama
# *******************************************************
# checking openweather for city number 463 : urucara
# *******************************************************
# checking openweather for city number 464 : nyazepetrovsk
# *******************************************************
# checking openweather for city number 465 : ovsyanka
# *******************************************************
# checking openweather for city number 466 : kodinsk
# *******************************************************
# checking openweather for city number 467 : laguna
# *******************************************************
# checking openweather for city number 468 : villa maria
# *******************************************************
# checking openweather for city number 469 : biak
# *******************************************************
# checking openweather for city number 470 : miri
# *******************************************************
# checking openweather for city number 471 : cap malheureux
# *******************************************************
# checking openweather for city number 472 : elizabeth city
# *******************************************************
# checking openweather for city number 473 : mutsamudu
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 474 : sobolevo
# *******************************************************
# checking openweather for city number 475 : luderitz
# *******************************************************
# checking openweather for city number 476 : mount gambier
# *******************************************************
# checking openweather for city number 477 : labuhan
# *******************************************************
# checking openweather for city number 478 : jujuy
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 479 : latung
# *******************************************************
# checking openweather for city number 480 : bonfim
# *******************************************************
# checking openweather for city number 481 : matamoros
# *******************************************************
# checking openweather for city number 482 : madison
# *******************************************************
# checking openweather for city number 483 : sambava
# *******************************************************
# checking openweather for city number 484 : dolbeau
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 485 : lydenburg
# *******************************************************
# checking openweather for city number 486 : gandajika
# *******************************************************
# checking openweather for city number 487 : ongandjera
# *******************************************************
# checking openweather for city number 488 : antalaha
# *******************************************************
# checking openweather for city number 489 : alexandria
# *******************************************************
# checking openweather for city number 490 : gisborne
# *******************************************************
# checking openweather for city number 491 : kudahuvadhoo
# *******************************************************
# checking openweather for city number 492 : katsuura
# *******************************************************
# checking openweather for city number 493 : jiddah
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 494 : luanda
# *******************************************************
# checking openweather for city number 495 : daoukro
# *******************************************************
# checking openweather for city number 496 : tawkar
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 497 : del rio
# *******************************************************
# checking openweather for city number 498 : new plymouth
# *******************************************************
# checking openweather for city number 499 : yeppoon
# *******************************************************
# checking openweather for city number 500 : sao francisco do sul
# *******************************************************
# checking openweather for city number 501 : ilhabela
# *******************************************************
# checking openweather for city number 502 : esperance
# *******************************************************
# checking openweather for city number 503 : calvinia
# *******************************************************
# checking openweather for city number 504 : san francisco
# *******************************************************
# checking openweather for city number 505 : mazamari
# *******************************************************
# checking openweather for city number 506 : havre-saint-pierre
# *******************************************************
# checking openweather for city number 507 : bridgeton
# *******************************************************
# checking openweather for city number 508 : kieta
# *******************************************************
# checking openweather for city number 509 : cabedelo
# *******************************************************
# checking openweather for city number 510 : ponta delgada
# *******************************************************
# checking openweather for city number 511 : fort saint james
# *******************************************************
# checking openweather for city number 512 : golden
# *******************************************************
# checking openweather for city number 513 : slave lake
# *******************************************************
# checking openweather for city number 514 : kijang
# *******************************************************
# checking openweather for city number 515 : montepuez
# *******************************************************
# checking openweather for city number 516 : luanshya
# *******************************************************
# checking openweather for city number 517 : shakawe
# *******************************************************
# checking openweather for city number 518 : prince rupert
# *******************************************************
# checking openweather for city number 519 : liusha
# *******************************************************
# checking openweather for city number 520 : cidreira
# *******************************************************
# checking openweather for city number 521 : khani
# *******************************************************
# checking openweather for city number 522 : erzin
# *******************************************************
# checking openweather for city number 523 : kahului
# *******************************************************
# checking openweather for city number 524 : vila velha
# *******************************************************
# checking openweather for city number 525 : sussex
# *******************************************************
# checking openweather for city number 526 : orapa
# *******************************************************
# checking openweather for city number 527 : pitimbu
# *******************************************************
# checking openweather for city number 528 : morondava
# *******************************************************
# checking openweather for city number 529 : argelia
# *******************************************************
# checking openweather for city number 530 : wicklow
# *******************************************************
# checking openweather for city number 531 : riyadh
# *******************************************************
# checking openweather for city number 532 : aripuana
# *******************************************************
# checking openweather for city number 533 : flin flon
# *******************************************************
# checking openweather for city number 534 : tra vinh
# *******************************************************
# checking openweather for city number 535 : issoire
# *******************************************************
# checking openweather for city number 536 : jizan
# *******************************************************
# checking openweather for city number 537 : tomatlan
# *******************************************************
# checking openweather for city number 538 : berlevag
# *******************************************************
# checking openweather for city number 539 : thinadhoo
# *******************************************************
# checking openweather for city number 540 : mitsamiouli
# *******************************************************
# checking openweather for city number 541 : kalawit
# *******************************************************
# checking openweather for city number 542 : barpeta
# *******************************************************
# checking openweather for city number 543 : charlottetown
# *******************************************************
# checking openweather for city number 544 : sayat
# *******************************************************
# checking openweather for city number 545 : tiznit
# *******************************************************
# checking openweather for city number 546 : verkhnyaya inta
# *******************************************************
# checking openweather for city number 547 : orocue
# *******************************************************
# checking openweather for city number 548 : akureyri
# *******************************************************
# checking openweather for city number 549 : boca do acre
# *******************************************************
# checking openweather for city number 550 : atar
# *******************************************************
# checking openweather for city number 551 : puerto gaitan
# *******************************************************
# checking openweather for city number 552 : moose factory
# *******************************************************
# checking openweather for city number 553 : thyolo
# *******************************************************
# checking openweather for city number 554 : pilar
# *******************************************************
# checking openweather for city number 555 : erenhot
# *******************************************************
# checking openweather for city number 556 : radcliff
# *******************************************************
# checking openweather for city number 557 : formosa do rio preto
# *******************************************************
# checking openweather for city number 558 : gimli
# *******************************************************
# checking openweather for city number 559 : haibowan
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 560 : kacuni
# *******************************************************
# checking openweather for city number 561 : pangnirtung
# *******************************************************
# checking openweather for city number 562 : kokstad
# *******************************************************
# checking openweather for city number 563 : jerome
# *******************************************************
# checking openweather for city number 564 : milingimbi
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 565 : gubkinskiy
# *******************************************************
# checking openweather for city number 566 : salinopolis
# *******************************************************
# checking openweather for city number 567 : peniche
# *******************************************************
# checking openweather for city number 568 : lompoc
# *******************************************************
# checking openweather for city number 569 : boden
# *******************************************************
# checking openweather for city number 570 : dukat
# *******************************************************
# checking openweather for city number 571 : natal
# *******************************************************
# checking openweather for city number 572 : koster
# *******************************************************
# checking openweather for city number 573 : bolungarvik
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 574 : stornoway
# *******************************************************
# checking openweather for city number 575 : kuche
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 576 : highland springs
# *******************************************************
# checking openweather for city number 577 : yulara
# *******************************************************
# checking openweather for city number 578 : manono
# *******************************************************
# checking openweather for city number 579 : lamballe
# *******************************************************
# checking openweather for city number 580 : popondetta
# *******************************************************
# checking openweather for city number 581 : phek
# *******************************************************
# checking openweather for city number 582 : te anau
# *******************************************************
# checking openweather for city number 583 : mizan teferi
# *******************************************************
# checking openweather for city number 584 : pontes e lacerda
# *******************************************************
# checking openweather for city number 585 : puri
# *******************************************************
# checking openweather for city number 586 : muravlenko
# *******************************************************
# checking openweather for city number 587 : sioux lookout
# *******************************************************
# checking openweather for city number 588 : bilma
# *******************************************************
# checking openweather for city number 589 : waldkirchen
# *******************************************************
# checking openweather for city number 590 : san buenaventura
# *******************************************************
# checking openweather for city number 591 : richards bay
# *******************************************************
# checking openweather for city number 592 : mrirt
# *** No Weather Record, removing from file ***
# *******************************************************
# checking openweather for city number 593 : calama
# *******************************************************
# checking openweather for city number 594 : wageningen
# *******************************************************
# checking openweather for city number 595 : sulina
# *******************************************************
# checking openweather for city number 596 : ormara
# *******************************************************
# checking openweather for city number 597 : kuusamo
# *******************************************************
# checking openweather for city number 598 : villa carlos paz
# *******************************************************
# checking openweather for city number 599 : sept-iles
# number of cities left = 544

# %%
#######################################################
#03        Outfile                                    #
#   write complete df to csv file and display head.   # 
#######################################################

city_weather.to_csv(output_data_file, index=False, header=True)
city_weather.head(5)
# Out:
#                     city   temp humid   wind clouds      lat      lng maxtemp  \
# 0            worthington   51.6    62   4.09     75  40.0931  -83.018      54
# 1         port elizabeth   60.8    88  17.27     75  -33.918  25.5701    60.8
# 2  mayor pablo lagerenza  73.54    59   6.87     98 -19.9309 -60.7718   73.54
# 3              otradnoye  52.63    62   6.71      0  59.7775  30.8181      55
# 4                   asau  42.01    66   1.92      0  46.4333     26.4   42.01
#
#   country      local_date_time
# 0      US  2021-05-10 17:28:07
# 1      ZA  2021-05-10 23:28:07
# 2      PY  2021-05-10 17:28:07
# 3      RU  2021-05-11 00:28:08
# 4      RO  2021-05-11 00:28:08

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.

# %%
###############################################################
#04        Clean Data                                         #
#   a- sort df by humid and check if top record is gt 100.    # 
#   b- create clean df, dropping any humidities gt 100.       # 
#   c- check clean df len, write warning if lt 500 records.   #
###############################################################

#a
del_indexes2 =[]
city_weather.sort_values("humid",inplace=True,ascending=False)
city_weather.reset_index(inplace=True, drop=True)
if city_weather["humid"][0] > 100:
    del_indexes2 = city_weather[city_weather["humid"] > 100].index

#b
clean_city_weather = city_weather.drop(del_indexes2, inplace=False)
clean_city_weather.reset_index(inplace=True,drop=True)
    
#c    
if len(clean_city_weather) < 500:
    print('\033[91m' + "WARNING!!  Number of cities left = " + str(len(clean_city_weather)) + '\033[0m')
else:
    print(f"number of cities left = {len(clean_city_weather)}")
# Out:
# number of cities left = 544

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
####################################################
#05    ScatterPlot-1 Lat v Temp                    #
#  a- scatterplot lattitude against temperature.   #
#  b- save image to png file.                      #
####################################################

#a
plt.figure(figsize=(9,5))
plt.scatter(clean_city_weather["lat"],clean_city_weather["temp"])
plt.xlabel("Lattitude")
plt.ylabel("Temperature (F)")
plt.title("Lattitude vs Temperature")
plt.show()

#b
plt.savefig("output_data/lat_vs_temp.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# The relationship between lattitude and temperature shows an increase in temperature approaching zero degrees lattitude from both the positive and negative sides, as well as higher temperatures away from zero towards the positive.  This is to be expected as the equator (zero degrees lat) receives the most amount of sun.  Also, as it is currently summer in the northern hemisphere (positive lat) we see slighlty higher temperatures to the right of zero as compared to the left (where it is currently winter).

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#################################################
#06    ScatterPlot-2 Lat v Humidity             #
#  a- scatterplot lattitude against humidity.   #
#  b- save image to png file.                   #
#################################################

#a
plt.figure(figsize=(9,5))
plt.scatter(clean_city_weather["lat"],clean_city_weather["humid"])
plt.xlabel("Lattitude")
plt.ylabel("Relative Humidity (%)")
plt.title("Lattitude vs Humidity")
plt.show()

#b
plt.savefig("output_data/lat_vs_humid.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# Comparing lattitude to relative humidity levels shows no real trend. We do see some empty patches of low humidity levels and minor clustering of higher levels but nothing appears related to lattitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
###################################################
#07    ScatterPlot-3 Lat v Cloudiness             #
#  a- scatterplot lattitude against cloudiness.   #
#  b- save image to png file.                     #
###################################################

#a
plt.figure(figsize=(9,5))
plt.scatter(clean_city_weather["lat"],clean_city_weather["clouds"])
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")
plt.title("Lattitude vs Cloudiness")
plt.show()

#b
plt.savefig("output_data/lat_vs_clouds.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# There is no visible relationship between lattitude and cloudiness.  There does appear to be horizontal bands of certain cloud cover percentages, with heavier clustering at the extremes.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
###################################################
#08    ScatterPlot-4 Lat v Wind Speed             #
#  a- scatterplot lattitude against wind speed.   #
#  b- save image to png file.                     #
###################################################

#a
plt.figure(figsize=(9,5))
plt.scatter(clean_city_weather["lat"],clean_city_weather["wind"])
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Lattitude vs Wind Speed")
plt.show()

#b
plt.savefig("output_data/lat_vs_wind.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# Looking at lattitude vs windspeed shows no relationship.  We do see that at the moment of this extraction global wind speeds are generally low for this sample,

# %% [markdown]
# ## Linear Regression

# %%
##############################################################################################
# 10     LinePlot Function (lineplot)                                                        #
#          > Creates scatterplot, linear regression, or line over scatterplot graph.         #
#   Positional Inputs[Required]: x-axis, y-axis= x and y coordinates for data points.        #
#        xy = tuple with x and y coordinates to annotate slope-intercept formula.            #
#   Keyword Inputs[Optional]: title- title for the graph,  x_label & y_label- axes labels,   #
#        type = "line" - produces linear regression graph only.                              #
#        type = "plot" - produces scatter plot graph only.                                   #
#        type = "both" (or any value not "line" or "plot") - produces line over scatter.     #
#                                                                                            #
#   a- ensure axes are lists for scipy call, set title and labels.                           #
#   b- if not line graph only, produce scatterplot, exit if plot only.                       #
#   c- call scipy linregress() for regression line variables, create regression line.        #
#   d- create linear regression chart.                                                       #
##############################################################################################

def lineplot (xparm,yparm,xy,title="",x_label="",y_label="",type="both"):
#a    
    x_axis = list(xparm) 
    y_axis = list(yparm)
    plt.figure(figsize=(9,5))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)

#b    
    if type != "line":
        plt.scatter(x_axis,y_axis)
        plt.show()
        if type == "plot":
            return
#c        
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis,y_axis)
    regress_line = slope * np.asarray(x_axis) + intercept    # convert sequence to array for floatpoint *
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
#d     
    plt.plot(x_axis, regress_line,"r-")
    plt.annotate(line_eq,xy,fontsize=12,color="r")
    plt.show()

# %%
#########################################
#11    Hemisphere df's                  # 
#   a- create northern hemisphere df.   #
#   b- create southern hemisphere df.   #
#########################################

#a
north_city_weather = clean_city_weather[clean_city_weather["lat"] >= 0]
print(f"Number of cities in Northern Hemispher : {len(north_city_weather)}")

#b
south_city_weather = clean_city_weather[clean_city_weather["lat"] < 0]
print(f"Number of cities in Southern Hemispher : {len(south_city_weather)}")
# Out:
# Number of cities in Northern Hemispher : 364
# Number of cities in Southern Hemispher : 180

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#############################################
#12  Regression1 North lat vs Maxtemp       # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x12 = north_city_weather["lat"]
y12 = north_city_weather["maxtemp"]
title12 = "Northern Hemisphere:  Max Temp vs. Latitude"
xlabel12 = "Latutude"
ylabel12 = "Temperature (F)"
xy12 = (20,60)

#b
lineplot(x12, y12, xy12, title=title12, x_label=xlabel12, y_label=ylabel12, type="both")
plt.savefig("output_data/north_lat_vs_maxtemp.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# Because lattitudes away from the equator see less sun, it is very evident that the further from the equator, the cooler the temperatures.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#############################################
#13    Regression2 South lat v Maxtemp      # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x13 = south_city_weather["lat"]
y13 = south_city_weather["maxtemp"]
title13 = "Southern Hemisphere:  Max Temp vs. Latitude"
xlabel13 = "Latutude"
ylabel13 = "Temperature (F)"
xy13 = (-40,45)

#b
lineplot(x13, y13, xy13, title=title13, x_label=xlabel13, y_label=ylabel13, type="both")
plt.savefig("output_data/south_lat_vs_maxtemp.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# Because lattitudes away from the equator see less sun, it is very evident that the further from the equator, the cooler the temperatures, whether north or south. the southern hemisphere does show a steeper gradient because of their winter creating cooler temperatures than the north.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#############################################
#14    Regression3 North lat v Humidity     # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x14 = north_city_weather["lat"]
y14 = north_city_weather["humid"]
title14 = "Northern Hemisphere:  Humidity vs. Latitude"
xlabel14 = "Latutude"
ylabel14 = "Relative Humidity (%)"
xy14 = (20,50)

#b
lineplot(x14, y14, xy14, title=title14, x_label=xlabel14, y_label=ylabel14, type="both")
plt.savefig("output_data/north_lat_vs_humid.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# the decrease in humidity away from the equator is minor and should not be considered significant, though possibly explained by warm, wet tropical conditions closer to the equator.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#############################################
#15    Regression4 South lat v Humidity     # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x15 = south_city_weather["lat"]
y15 = south_city_weather["humid"]
title15 = "Southern Hemisphere:  Humidity vs. Latitude"
xlabel15 = "Latutude"
ylabel15 = "Relative Humidity (%)"
xy15 = (-40,60)

#b
lineplot(x15, y15, xy15, title=title15, x_label=xlabel15, y_label=ylabel15, type="both")
plt.savefig("output_data/south_lat_vs_humid.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# the southern hemisphere shows an even less significant gradient of relationship between humidity and lattitude.  it is showing a very small increase in humidty further from the equator, very similiar slope, in the opposite condition as the northern.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#############################################
#16    Regression5 North lat v Cloudiness   # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x16 = north_city_weather["lat"]
y16 = north_city_weather["clouds"]
title16 = "Northern Hemisphere:  Cloudiness vs. Latitude"
xlabel16 = "Latutude"
ylabel16 = "Cloud Cover (%)"
xy16 = (20,45)

#b
lineplot(x16, y16, xy16, title=title16, x_label=xlabel16, y_label=ylabel16, type="both")
plt.savefig("output_data/north_lat_vs_clouds.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# linear regression shows no significant coorelation between cloudiness and lattitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#############################################
#17    Regression6 South lat v Cloudiness   # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x17 = south_city_weather["lat"]
y17 = south_city_weather["clouds"]
title17 = "Southern Hemisphere:  Cloudiness vs. Latitude"
xlabel17 = "Latutude"
ylabel17= "Cloud Cover (%)"
xy17 = (-40,40)

#b
lineplot(x17, y17, xy17, title=title17, x_label=xlabel17, y_label=ylabel17, type="both")
plt.savefig("output_data/south_lat_vs_clouds.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# although the southern hemisphere shows a regression line 11 times steeper than the northern, with an increase in cloudiness further from the equator, it is unlikely that there is any causation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#############################################
#18    Regression7 North lat v WindSpeed    # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x18 = north_city_weather["lat"]
y18 = north_city_weather["wind"]
title18 = "Northern Hemisphere:  Wind Speed vs. Latitude"
xlabel18 = "Latutude"
ylabel18= "Wind Speed(mph)"
xy = (25,10)

#b
lineplot(x18, y18, xy, title=title18, x_label=xlabel18, y_label=ylabel18, type="both")
plt.savefig("output_data/north_lat_vs_wind.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# linear regression shows no significant coorelation between windspeed and lattitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#############################################
#19    Regression8 South lat v Cloudiness   # 
#   a- set datapoints, title, and labels.   #
#   b- call lineplot() to produce graph.    #
#############################################

#a
x19 = south_city_weather["lat"]
y19 = south_city_weather["wind"]
title19 = "Southern Hemisphere:  Wind Speed vs. Latitude"
xlabel19 = "Latutude"
ylabel19= "Wind Speed(mph)"
xy = (-40,10)

#b
lineplot(x19, y19, xy, title=title19, x_label=xlabel19, y_label=ylabel19, type="both")
plt.savefig("output_data/south_lat_vs_wind.png")
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">

# %% [markdown]
# though the regression line shows a slight decrease in wind speeds towards the equator from the southern hemisphere, there data does not support a relationship.
